# %% [markdown]
# # Chapter 9 Lab: Unsupervised Learning
#
# ```{admonition} Lab Objectives
# :class: tip
# - Implement k-means clustering
# - Build hierarchical clustering
# - Apply PCA for dimensionality reduction
# - Create autoencoders
# - Evaluate clustering quality
# ```
#
# ## Lab Overview
# 1. K-means and variants
# 2. Hierarchical clustering
# 3. DBSCAN density-based clustering
# 4. PCA and t-SNE
# 5. Autoencoders

# %% [markdown]
# ## Exercise 1: K-Means Clustering
#
# Implement k-means from scratch.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

class KMeans:
    def __init__(self, n_clusters=3, max_iters=100, random_state=None):
        self.n_clusters = n_clusters
        self.max_iters = max_iters
        self.random_state = random_state
        self.centroids = None
        self.labels = None
        
    def fit(self, X):
        """
        TODO: Implement k-means algorithm
        
        Algorithm:
        1. Initialize centroids randomly
        2. Assign points to nearest centroid
        3. Update centroids as mean of assigned points
        4. Repeat 2-3 until convergence
        """
        # YOUR CODE HERE
        pass
        
    def predict(self, X):
        """Assign points to nearest centroid"""
        # YOUR CODE HERE
        pass
        
    def inertia(self, X):
        """Sum of squared distances to nearest centroid"""
        # YOUR CODE HERE
        pass

# Generate data
X, y_true = make_blobs(n_samples=300, centers=4, random_state=42)

# Fit k-means
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X)

# Visualize
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=y_true, cmap='viridis', alpha=0.6)
plt.title('True Labels')

plt.subplot(1, 2, 2)
plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels, cmap='viridis', alpha=0.6)
plt.scatter(kmeans.centroids[:, 0], kmeans.centroids[:, 1], 
            marker='x', s=300, linewidths=3, color='r', label='Centroids')
plt.title('K-Means Clustering')
plt.legend()

plt.tight_layout()
plt.show()

# Elbow method
inertias = []
K_range = range(1, 11)
for k in K_range:
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X)
    inertias.append(km.inertia(X))

plt.plot(K_range, inertias, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# ## Exercise 2: Hierarchical Clustering
#
# Implement agglomerative clustering.

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist, squareform

def hierarchical_clustering(X, method='ward'):
    """
    TODO: Implement hierarchical clustering
    
    Methods: 'single', 'complete', 'average', 'ward'
    
    Algorithm:
    1. Start with each point as a cluster
    2. Merge closest clusters
    3. Repeat until one cluster remains
    4. Record merge history
    """
    # YOUR CODE HERE
    pass

# Generate data
X, _ = make_blobs(n_samples=50, centers=3, random_state=42)

# Perform clustering
linkage_matrix = linkage(X, method='ward')

# Plot dendrogram
plt.figure(figsize=(12, 6))
dendrogram(linkage_matrix)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# Compare linkage methods
methods = ['single', 'complete', 'average', 'ward']
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

for ax, method in zip(axes.ravel(), methods):
    linkage_matrix = linkage(X, method=method)
    dendrogram(linkage_matrix, ax=ax)
    ax.set_title(f'{method.capitalize()} Linkage')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise 3: DBSCAN
#
# Implement density-based clustering.

# %%
class DBSCAN:
    def __init__(self, eps=0.5, min_samples=5):
        self.eps = eps
        self.min_samples = min_samples
        self.labels = None
        
    def fit(self, X):
        """
        TODO: Implement DBSCAN
        
        Algorithm:
        1. For each point:
           a. Find neighbors within eps
           b. If enough neighbors (>= min_samples), start cluster
           c. Expand cluster by adding neighbors' neighbors
        2. Mark remaining points as noise
        """
        # YOUR CODE HERE
        pass
        
    def region_query(self, X, point_idx):
        """Find all points within eps of point_idx"""
        # YOUR CODE HERE
        pass

# Generate data with noise
from sklearn.datasets import make_moons
X, _ = make_moons(n_samples=200, noise=0.05, random_state=42)
# Add noise points
noise = np.random.uniform(X.min(), X.max(), (20, 2))
X = np.vstack([X, noise])

# Fit DBSCAN
dbscan = DBSCAN(eps=0.3, min_samples=5)
dbscan.fit(X)

# Visualize
plt.scatter(X[:, 0], X[:, 1], c=dbscan.labels, cmap='viridis')
plt.title('DBSCAN Clustering (noise = -1)')
plt.show()

# Compare with k-means
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].scatter(X[:, 0], X[:, 1], c=kmeans.labels, cmap='viridis')
axes[0].set_title('K-Means')
axes[1].scatter(X[:, 0], X[:, 1], c=dbscan.labels, cmap='viridis')
axes[1].set_title('DBSCAN')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise 4: PCA and Dimensionality Reduction
#
# Implement Principal Component Analysis.

# %%
class PCA:
    def __init__(self, n_components=2):
        self.n_components = n_components
        self.components = None
        self.mean = None
        self.explained_variance = None
        
    def fit(self, X):
        """
        TODO: Implement PCA
        
        Algorithm:
        1. Center data (subtract mean)
        2. Compute covariance matrix
        3. Compute eigenvectors and eigenvalues
        4. Sort by eigenvalues (descending)
        5. Select top n_components eigenvectors
        """
        # YOUR CODE HERE
        pass
        
    def transform(self, X):
        """Project data onto principal components"""
        X_centered = X - self.mean
        return X_centered @ self.components.T
        
    def inverse_transform(self, X_transformed):
        """Reconstruct original data"""
        return X_transformed @ self.components + self.mean

# Load iris dataset
from sklearn.datasets import load_iris
iris = load_iris()
X, y = iris.data, iris.target

# Apply PCA
pca = PCA(n_components=2)
pca.fit(X)
X_pca = pca.transform(X)

# Visualize
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('PCA of Iris Dataset')
plt.colorbar(label='Class')

# Explained variance
plt.subplot(1, 2, 2)
variance_ratios = pca.explained_variance / pca.explained_variance.sum()
plt.bar(range(1, len(variance_ratios)+1), variance_ratios)
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Variance Explained')

plt.tight_layout()
plt.show()

print(f'Total variance explained: {variance_ratios.sum():.2%}')

# %% [markdown]
# ## Exercise 5: Autoencoder
#
# Build autoencoder for dimensionality reduction.

# %%
import torch
import torch.nn as nn
from torchvision import datasets, transforms

class Autoencoder(nn.Module):
    def __init__(self, input_dim=784, latent_dim=32):
        super(Autoencoder, self).__init__()
        """
        TODO: Build autoencoder
        
        Encoder: input -> hidden -> latent
        Decoder: latent -> hidden -> output
        """
        # YOUR CODE HERE
        pass
        
    def encode(self, x):
        # YOUR CODE HERE
        pass
        
    def decode(self, z):
        # YOUR CODE HERE
        pass
        
    def forward(self, x):
        z = self.encode(x)
        reconstruction = self.decode(z)
        return reconstruction, z

# Load MNIST
transform = transforms.Compose([transforms.ToTensor()])
train_dataset = datasets.MNIST('./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)

# Train autoencoder
model = Autoencoder(latent_dim=2)  # 2D latent space for visualization
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

for epoch in range(10):
    total_loss = 0
    for data, _ in train_loader:
        data = data.view(-1, 28*28)
        optimizer.zero_grad()
        reconstruction, _ = model(data)
        loss = criterion(reconstruction, data)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    print(f'Epoch {epoch+1}, Loss: {total_loss/len(train_loader):.4f}')

# Visualize latent space
model.eval()
latent_vectors = []
labels = []

with torch.no_grad():
    for data, label in train_loader:
        data = data.view(-1, 28*28)
        _, z = model(data)
        latent_vectors.append(z.numpy())
        labels.append(label.numpy())

latent_vectors = np.vstack(latent_vectors)
labels = np.hstack(labels)

plt.figure(figsize=(10, 8))
plt.scatter(latent_vectors[:, 0], latent_vectors[:, 1], c=labels, cmap='tab10', alpha=0.5)
plt.colorbar(label='Digit')
plt.title('2D Latent Space')
plt.xlabel('Latent Dimension 1')
plt.ylabel('Latent Dimension 2')
plt.show()

# %% [markdown]
# ## Challenge: VAE and Generative Models
#
# Implement Variational Autoencoder.

# %%
class VAE(nn.Module):
    def __init__(self, input_dim=784, latent_dim=20):
        super(VAE, self).__init__()
        """
        CHALLENGE: Implement VAE
        
        Encoder outputs: mean and log_variance
        Reparameterization trick: z = mean + std * epsilon
        Loss: reconstruction + KL divergence
        """
        # YOUR CODE HERE
        pass
        
    def reparameterize(self, mu, logvar):
        """Sample from N(mu, var)"""
        # YOUR CODE HERE
        pass
        
    def loss_function(self, recon_x, x, mu, logvar):
        """VAE loss = reconstruction + KL divergence"""
        # YOUR CODE HERE
        pass

# %% [markdown]
# ## Lab Report
#
# ### Deliverables
# - [ ] K-means implementation
# - [ ] Hierarchical clustering
# - [ ] DBSCAN
# - [ ] PCA from scratch
# - [ ] Autoencoder
#
# ### Discussion
# 1. When should you use each clustering algorithm?
# 2. How do you choose the number of clusters?
# 3. Compare PCA vs autoencoders
# 4. What are advantages of unsupervised learning?
