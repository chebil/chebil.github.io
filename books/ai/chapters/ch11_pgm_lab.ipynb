# %% [markdown]
# # Chapter 11 Lab: Probabilistic Graphical Models
#
# ```{admonition} Lab Objectives
# :class: tip
# - Implement Bayesian Networks
# - Build Markov Random Fields
# - Perform exact inference
# - Apply approximate inference (sampling)
# - Use PGMs for reasoning under uncertainty
# ```
#
# ## Lab Overview
# 1. Bayesian Network construction
# 2. Variable elimination
# 3. MCMC sampling
# 4. Hidden Markov Models
# 5. Conditional Random Fields

# %% [markdown]
# ## Exercise 1: Bayesian Network
#
# Build a simple Bayesian Network.

# %%
import numpy as np
from typing import Dict, List, Tuple

class BayesianNetwork:
    def __init__(self):
        self.nodes = {}
        self.edges = []
        self.cpts = {}  # Conditional Probability Tables
        
    def add_node(self, name: str, parents: List[str] = None):
        """
        TODO: Add node to network
        Store node and its parents
        """
        # YOUR CODE HERE
        pass
        
    def set_cpt(self, node: str, cpt: np.ndarray):
        """Set conditional probability table for node"""
        self.cpts[node] = cpt
        
    def probability(self, evidence: Dict[str, int]) -> float:
        """
        TODO: Compute joint probability P(evidence)
        Use chain rule: P(X1,...,Xn) = ∏ P(Xi | Parents(Xi))
        """
        # YOUR CODE HERE
        pass

# Example: Student Bayesian Network
# Difficulty -> Grade <- Intelligence
# Intelligence -> SAT

bn = BayesianNetwork()

# Add nodes
bn.add_node('Difficulty')
bn.add_node('Intelligence')
bn.add_node('Grade', parents=['Difficulty', 'Intelligence'])
bn.add_node('SAT', parents=['Intelligence'])

# Set CPTs
# P(Difficulty)
bn.set_cpt('Difficulty', np.array([0.6, 0.4]))  # [easy, hard]

# P(Intelligence)
bn.set_cpt('Intelligence', np.array([0.7, 0.3]))  # [low, high]

# P(Grade | Difficulty, Intelligence)
bn.set_cpt('Grade', np.array([
    [[0.3, 0.4, 0.3], [0.05, 0.25, 0.7]],  # Difficulty=easy
    [[0.5, 0.3, 0.2], [0.2, 0.3, 0.5]]     # Difficulty=hard
]))  # [A, B, C] for each Intelligence level

# Test
evidence = {'Difficulty': 0, 'Intelligence': 1, 'Grade': 2, 'SAT': 1}
prob = bn.probability(evidence)
print(f'P(evidence) = {prob}')

# %% [markdown]
# ## Exercise 2: Variable Elimination
#
# Implement exact inference algorithm.

# %%
class Factor:
    def __init__(self, variables: List[str], values: np.ndarray):
        self.variables = variables
        self.values = values
        
    def marginalize(self, variable: str):
        """
        TODO: Sum out a variable from factor
        Return new factor with variable removed
        """
        # YOUR CODE HERE
        pass
        
    def multiply(self, other: 'Factor'):
        """
        TODO: Multiply two factors
        Align dimensions and multiply values
        """
        # YOUR CODE HERE
        pass

def variable_elimination(bn: BayesianNetwork, query: str, evidence: Dict[str, int], 
                        elimination_order: List[str]) -> np.ndarray:
    """
    TODO: Implement variable elimination
    
    Algorithm:
    1. Create initial factors from CPTs
    2. Reduce factors using evidence
    3. For each variable in elimination order:
       - Multiply factors containing that variable
       - Sum out the variable
    4. Multiply remaining factors
    5. Normalize
    """
    # YOUR CODE HERE
    pass

# Test: P(Grade | Intelligence=high)
result = variable_elimination(bn, 'Grade', {'Intelligence': 1}, ['Difficulty', 'SAT'])
print(f'P(Grade | Intelligence=high) = {result}')

# %% [markdown]
# ## Exercise 3: MCMC Sampling
#
# Implement Gibbs sampling for inference.

# %%
def gibbs_sampling(bn: BayesianNetwork, query: str, evidence: Dict[str, int],
                   num_samples: int = 10000) -> np.ndarray:
    """
    TODO: Implement Gibbs sampling
    
    Algorithm:
    1. Initialize non-evidence variables randomly
    2. For each iteration:
       - For each non-evidence variable:
         a. Sample from P(var | all other variables)
         b. Update variable value
    3. Collect samples and compute empirical distribution
    """
    # YOUR CODE HERE
    pass

def sample_from_conditional(bn: BayesianNetwork, var: str, 
                           current_state: Dict[str, int]) -> int:
    """Sample variable given Markov blanket"""
    # YOUR CODE HERE
    pass

# Test and compare with exact inference
samples = gibbs_sampling(bn, 'Grade', {'Intelligence': 1}, num_samples=10000)
print(f'Approximate P(Grade | Intelligence=high) = {samples}')
print(f'Exact result: {result}')

# %% [markdown]
# ## Exercise 4: Hidden Markov Model
#
# Implement Forward-Backward algorithm.

# %%
class HMM:
    def __init__(self, n_states, n_observations):
        self.n_states = n_states
        self.n_observations = n_observations
        self.start_prob = None  # π
        self.transition_prob = None  # A
        self.emission_prob = None  # B
        
    def forward(self, observations: List[int]) -> np.ndarray:
        """
        TODO: Implement forward algorithm
        
        α_t(i) = P(o_1,...,o_t, s_t=i)
        
        Recursion:
        α_t(j) = [Σ_i α_{t-1}(i) * a_{ij}] * b_j(o_t)
        """
        # YOUR CODE HERE
        pass
        
    def backward(self, observations: List[int]) -> np.ndarray:
        """
        TODO: Implement backward algorithm
        
        β_t(i) = P(o_{t+1},...,o_T | s_t=i)
        """
        # YOUR CODE HERE
        pass
        
    def viterbi(self, observations: List[int]) -> List[int]:
        """
        TODO: Find most likely state sequence
        Dynamic programming to find argmax P(states | observations)
        """
        # YOUR CODE HERE
        pass

# Example: Weather HMM
hmm = HMM(n_states=2, n_observations=3)  # States: Rainy, Sunny; Obs: Walk, Shop, Clean
hmm.start_prob = np.array([0.6, 0.4])
hmm.transition_prob = np.array([[0.7, 0.3], [0.4, 0.6]])
hmm.emission_prob = np.array([[0.1, 0.4, 0.5], [0.6, 0.3, 0.1]])

# Test
observations = [0, 1, 2]  # Walk, Shop, Clean
forward_probs = hmm.forward(observations)
most_likely = hmm.viterbi(observations)
print(f'Most likely states: {most_likely}')

# %% [markdown]
# ## Exercise 5: Markov Random Field
#
# Implement belief propagation.

# %%
class MRF:
    """Markov Random Field with pairwise potentials"""
    
    def __init__(self):
        self.nodes = []
        self.edges = []
        self.node_potentials = {}
        self.edge_potentials = {}
        
    def loopy_belief_propagation(self, max_iterations=100, tolerance=1e-5):
        """
        TODO: Implement loopy BP
        
        Message passing:
        m_{i→j}(x_j) = Σ_{x_i} ψ(x_i) ψ(x_i, x_j) ∏_{k∈N(i)\j} m_{k→i}(x_i)
        """
        # YOUR CODE HERE
        pass

# Example: Image denoising with MRF
def create_denoising_mrf(noisy_image: np.ndarray) -> MRF:
    """Create MRF for image denoising"""
    # YOUR CODE HERE
    pass

# %% [markdown]
# ## Challenge: Structure Learning
#
# Learn BN structure from data.

# %%
def learn_structure(data: np.ndarray, score_function='BIC') -> BayesianNetwork:
    """
    CHALLENGE: Learn BN structure from data
    
    Use hill-climbing with structure score (BIC, AIC)
    Try edge additions, deletions, reversals
    """
    # YOUR CODE HERE
    pass

# %% [markdown]
# ## Lab Report
#
# ### Deliverables
# - [ ] Bayesian Network implementation
# - [ ] Variable elimination
# - [ ] Gibbs sampling
# - [ ] HMM with Viterbi
# - [ ] Comparison of exact vs approximate inference
#
# ### Discussion
# 1. When is exact inference tractable?
# 2. Compare sampling methods for approximate inference
# 3. How do HMMs differ from general BNs?
# 4. Applications of PGMs in real-world problems
