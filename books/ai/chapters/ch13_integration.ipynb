# %% [markdown]
# # Chapter 13: Integration and Hybrid AI
#
# ```{admonition} Learning Objectives
# :class: tip
# - Understand neuro-symbolic integration
# - Combine deductive and inductive reasoning
# - Design hybrid AI systems
# - Build end-to-end AI pipelines
# - Apply AI to real-world problems
# ```

# %% [markdown]
# ## 13.1 Neuro-Symbolic AI
#
# **Integration Approaches:**
#
# 1. **Neural networks for perception**
#    - Learn from raw data
#    - Extract features
#    - Handle uncertainty
#
# 2. **Symbolic reasoning for logic**
#    - Structured knowledge
#    - Explicit rules
#    - Explainable decisions
#
# 3. **Hybrid architecture**
#    - Neural perception → Symbolic reasoning
#    - Symbolic constraints → Neural learning
#    - Bidirectional information flow

# %% [markdown]
# ## 13.2 System Architecture
#
# ```
# Hybrid AI System:
#
# +------------------+
# |  Perception      |  <- Neural Networks
# |  (CNN/RNN)       |
# +------------------+
#         |
#         v
# +------------------+
# |  Feature         |  <- Embeddings
# |  Extraction      |
# +------------------+
#         |
#         v
# +------------------+
# |  Symbolic        |  <- Logic/KB
# |  Reasoning       |
# +------------------+
#         |
#         v
# +------------------+
# |  Decision        |  <- Planning/Search
# |  Making          |
# +------------------+
# ```

# %% [markdown]
# ## 13.3 Design Principles
#
# **1. Modularity**
# - Separate perception, reasoning, action
# - Clear interfaces between components
# - Independent testing and updates
#
# **2. Explainability**
# - Symbolic reasoning provides justifications
# - Neural attention shows what matters
# - Traceable decision paths
#
# **3. Robustness**
# - Neural handles noise and uncertainty
# - Symbolic ensures logical consistency
# - Hybrid provides redundancy
#
# **4. Efficiency**
# - Neural for fast perception
# - Symbolic for efficient search
# - Caching and incremental updates

# %% [markdown]
# ## 13.4 Implementation
#
# See: [ch13_integration_implementation.ipynb](ch13_integration_implementation.ipynb)
#
# Includes:
# - Neuro-symbolic architecture
# - End-to-end pipeline
# - Multi-component system
# - Real-world: Intelligent assistant demo
