# %% [markdown]
# # Chapter 9: Unsupervised Learning - Implementation

# %%
import numpy as np
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

print('Imports complete')

# %%
class KMeans:
    def __init__(self, k=3, max_iters=100):
        self.k = k
        self.max_iters = max_iters
    
    def fit(self, X):
        # Random initialization
        idx = np.random.choice(len(X), self.k, replace=False)
        self.centroids = X[idx]
        
        for _ in range(self.max_iters):
            # Assign points
            distances = np.sqrt(((X - self.centroids[:,np.newaxis])**2).sum(axis=2))
            labels = np.argmin(distances, axis=0)
            
            # Update centroids
            new_centroids = np.array([X[labels==i].mean(axis=0) for i in range(self.k)])
            
            if np.allclose(self.centroids, new_centroids):
                break
            
            self.centroids = new_centroids
        
        return labels

print('k-Means implemented')

# %%
def pca(X, n_components=2):
    # Center data
    X_centered = X - X.mean(axis=0)
    
    # Covariance matrix
    cov = np.cov(X_centered.T)
    
    # Eigendecomposition
    eigenvalues, eigenvectors = np.linalg.eig(cov)
    
    # Sort by eigenvalues
    idx = eigenvalues.argsort()[::-1]
    eigenvectors = eigenvectors[:, idx]
    
    # Project
    return X_centered @ eigenvectors[:, :n_components]

print('PCA implemented')

# %%
print('=== k-Means Example ===')
X, y_true = make_blobs(n_samples=300, centers=3, random_state=42)
kmeans = KMeans(k=3)
labels = kmeans.fit(X)
print(f'Clustered {len(X)} points into {kmeans.k} clusters')

# %% [markdown]
# ## Real-World: Customer Segmentation
#
# Clustering customers for targeted marketing.
